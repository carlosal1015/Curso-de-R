# %% [markdown]
# <h1><center>Cuarta clase (03/03/2018)</center></h1>
#
# <h2><center>Gráficos</center></h2>
# <a href="https://cran.r-project.org/web/packages/JGR/index.html">
#   <img style="float: right;" src="../images/jgrlogo.png" width="250"/>
# </a>
#
# Existen varias interfaces gráficas de usuario para R tales como Rattle, RKWard, JGR, y R Commander; en esta clase mostraremos ejemplos de creación de gráficas con las dos últimas dos IDE's mencionadas.
#
# **Java GUI for R** (Jaguar) es una interfaz gráfica de usuario universal y unificada para el lenguaje de programación R. Tiene un alto soporte. La idea es realizar gráficos de manera sencilla.
#
# En `JGR` se cargará ``ggplot2``, el cual se usa para gráficos y análisis estadístico con RStudio.
#
# Para empezar a usar Jaguar, seguiremos los siguientes pasos:
#
# 1. Dirigirse a la barra superior y dar click en `Packages & Data`.
# 2. Luego, dar click en `Package manager`.
#
# <p align="center">
#   <img src="../images/jgr.png"  width="450"/>
# </p>
# 3. A continuación se mostrará una gran lista, por favor seleccione los ítems marcados en ambas columnas como se muestra a continuación:
#
# <p align="center">
#   <img src="../images/parte1.png"  width="850"/>
# </p>
# <p align="center">
#   <img src="../images/parte2.png"  width="850"/>
# </p>
# <p align="center">
#   <img src="../images/parte3.png"  width="850"/>
# </p>
# <p align="center">
#   <img src="../images/parte4.png"  width="850"/>
# </p>
#
# > Estamos interesados en seleccionar los paquetes `ggplot2`, `plyr`, `XLConnect`, `Deducer` y `DeducerExtras`, para ello seleccionamos en ambos recuadros.
#
# > Nótese que cuando seleccione este último se abrirá una nueva consola.
# > Las dos opciones deben estar activadas.
# > En caso de no encontrar los paquetes mencionados, proceda a instalar desde la consola de RStudio.
#
#
# Filtrar archivos con Tipo de Archivo al abrir.
#
# La ventaja de usar Jaguar es que le entraga código en R que lo podemos reutilizar.
#
# > Para poder utilizar el paquete JGR, es necesario instalar la dependencia JavaGD.
# > Sabías que [ggplot2](http://ggplot2.tidyverse.org/index.html) fue creado en el año por el equipo de RStudio.
#
# ## Instrucciones
#
# 1. Dirigirse al panel superior y dar click en `Plot`.
# 2. Ahora, dar click en `Plot Builder`.
# 3. Clic en bar y arrastrar hasta Components
# 4. Arrastramos FREC hasta la cajita.
# 5. Clic en Ok.
#
# <p align="center">
#   <img src="../images/jgrplot.png"  width="450"/>
# </p>
#
# <p align="center">
#   <img src="../images/plot1.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/plot2.png"  width="850"/>
# </p>

# %%
setwd("~/Desktop/Repositorios/Curso-de-R-Studio/Clases/Cuarta clase")
# No es necesario volver a instalarlo si ya lo tiene.
#install.packages("JGR")
#install.packages("Deducer")
#install.packages("XLConnect")
#install.packages("DeducerExtras")

library(JGR)
library(Deducer)
library(XLConnect)
library(DeducerExtras)

JGR()

# Cargar desde JGR la base de datos de Calc.
bd <- readWorksheet(loadWorkbook('~/Desktop/Repositorios/Curso-de-R-Studio/Clases/Cuarta clase/Libro1.xlsx'),sheet=1)
# Out:
# #!/bin/sh
#
# export R_HOME="/Library/Frameworks/R.framework/Resources"
# export R_ARCH=""
# export R_LIBS="/Users/User/Library/R/3.3/library:/Library/Frameworks/R.framework/Versions/3.3/Resources/library"
# export R_LIBS_USER="~/Library/R/3.3/library"
# '/System/Library/Java/JavaVirtualMachines/1.6.0.jdk/Contents/Home/bin/java' -cp '/Users/User/Library/R/3.3/library/rJava/java/boot' -Drjava.class.path='/Users/User/Library/R/3.3/library/rJava/jri/JRI.jar:/Users/User/Library/R/3.3/library/JGR/java/JGR.jar:/Library/Frameworks/R.framework/Resources/etc/classes:/Library/Frameworks/R.framework/Resources/etc/classes/classes.jar' -Drjava.path='/Users/User/Library/R/3.3/library/rJava' -Dmain.class=org.rosuda.JGR.JGR  -Djgr.load.pkgs=yes  -Dr.arch= -Xdock:icon='/Users/User/Library/R/3.3/library/JGR/icons/JGR.icns' -Dcom.apple.mrj.application.apple.menu.about.name='JGR' -Xdock:name='JGR' -Dapple.laf.useScreenMenuBar=true -Dcom.apple.macos.useScreenMenuBar=true -Xrs -Xss5m RJavaClassLoader

# %%
# Código generado por JGR
library(ggplot2)
ggplot() +
    geom_bar(aes(y = ..count..,x = as.factor(FREC)),data=bd,colour = '#ff0000',fill = '#ff9900',alpha = 0.5)
bd1 <- bd[,c(6,7)]
head(bd1)
# Out:
#   FY  FX
# 1 119 53
# 2 112 64
# 3 101 70
# 4 103 56
# 5 116 61
# 6 104 65
# plot without title

# %%
par(mfrow = c(2,2))
bd1 <- bd[,c(6,7)]
head(bd1)
fig1 <- plot(bd1, type="p", main="Tìtulo principal", xlab="titulo x", ylab="tituloy", col="red")
fig2 <- plot(bd1, type="l", main="Tìtulo principal", xlab="titulo x", ylab="tituloy", col="red")
fig3 <- plot(bd1, type="s", main="Tìtulo principal", xlab="titulo x", ylab="tituloy", col="red")
# Out:
#   FY  FX
# 1 119 53
# 2 112 64
# 3 101 70
# 4 103 56
# 5 116 61
# 6 104 65
# Plot with title “Tìtulo principal”

# %% [markdown]
# Para aprender más sobre creación de gráficos hay que experimentar con cada uno de las gráficas que nos ofrece Jaguar. Nótese que cada cambio en la gráfica es un código.
#
# Clic en editar diálogo.
#
# > Hay que tener cuidado, no todas las opciones están disponibles para los gráficos.
#
# R Commander es una interfaz gráfica de usuario, así como Jaguar.

# %% [markdown]
# <p align="center">
#   <img src="../images/rcmdr1.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr2.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr3.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr4.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr5.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr6.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr7.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr8.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr9.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr10.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr11.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr12.png"  width="850"/>
# </p>
#
# <p align="center">
#   <img src="../images/rcmdr13.png"  width="850"/>
# </p>

# %%
library(Rcmdr)
Dataset <- readXL("/Users/User/Desktop/Repositorios/Curso-de-R-Studio/Clases/Cuarta clase/Libro1.xlsx",
       rownames=FALSE, header=TRUE, na="", sheet="Hoja1", stringsAsFactors=TRUE); Dataset
par(mfrow = c(2,2))
fig1 <- with(Dataset, Barplot(FACTOR, xlab="FACTOR", ylab="Frequency"))
fig2 <- with(Dataset, Hist(FREC, scale="frequency", breaks="Sturges", 
                   col="darkgray"))
library(colorspace, pos=17)
fig3 <- with(Dataset, pie(table(NIVEL), labels=levels(NIVEL), xlab="", ylab="",
                  main="Sector circular", col=rainbow_hcl(3)))
library(lattice, pos=18)
fig4 <- plot(FY ~ FX, type="p", pch=16, auto.key=list(border=TRUE), 
       par.settings=simpleTheme(pch=16), scales=list(x=list(relation='same'),
                                                     y=list(relation='same')), data=Dataset)
# Out:
#    Id FECHA      FACTOR NIVEL FREC FY  FX
# 1   1 2016-05-15 B      Q     4    119 53
# 2   2 2016-05-16 A      W     4    112 64
# 3   3 2016-05-17 B      W     1    101 70
# 4   4 2016-05-18 B      Q     3    103 56
# 5   5 2016-05-19 A      Q     2    116 61
# 6   6 2016-05-20 A      Q     4    104 65
# 7   7 2016-05-21 A      E     1    100 63
# 8   8 2016-05-22 C      W     1    119 50
# 9   9 2016-05-23 B      E     3    120 51
# 10 10 2016-05-24 C      Q     1    103 65
# 11 11 2016-05-25 A      E     5    120 50
# 12 12 2016-05-26 C      Q     1    106 61
# 13 13 2016-05-27 A      E     4    110 69
# 14 14 2016-05-28 C      E     3    104 54
# 15 15 2016-05-29 C      E     3    112 58
# 16 16 2016-05-30 C      Q     1    107 51
# 17 17 2016-05-31 A      E     3    115 61
# 18 18 2016-06-01 C      W     1    110 52
# 19 19 2016-06-02 B      W     1    107 64
# 20 20 2016-06-03 B      E     2    111 54
# 21 21 2016-06-04 C      W     2    107 61
# ...

# %%
bdiris <- iris
head(bdiris)
bdiris <- bdiris[,c(1,2)]

layout(matrix(c(1,2,3,3), 2, 2, byrow = T))
# layout.show(3)
# Para visualizar las posiciones de las gráficas ejecute el comando de arriba
plot(bdiris)
plot(bdiris, col="red")
plot(bdiris, col="blue")
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa
# plot without title

# %%
library(JGR)
library(Deducer)
library(XLConnect)

Libro1 <- readWorksheet(loadWorkbook('/Users/User/Desktop/Repositorios/Curso-de-R-Studio/Clases/Cuarta clase/Libro1.xlsx'),sheet=1); Libro1
ggplot() +
   geom_bar(aes(y = ..count..,x = NIVEL,fill = FREC),data=Libro1,position = position_dodge()) +
   facet_wrap(facets = ~FACTOR)

ggplot() +
   geom_boxplot(aes(y = FY,x = FACTOR,colour = NIVEL),data=Libro1,fill = '#ff0000',alpha = 0.1008)

ggplot() +
   geom_boxplot(aes(y = FY,x = NIVEL),data=Libro1,colour = '#ff0000',fill = '#ffff00',alpha = 0.5) +
   geom_dotplot(aes(x = NIVEL,y = FY),data=Libro1,colour = '#ff0000',fill = '#00ffff',alpha = 0.5,binaxis = 'y',stackdir = 'center') +
   facet_wrap(facets = ~FACTOR)
# Out:
#    Id FECHA      FACTOR NIVEL FREC FY  FX
# 1   1 2016-05-15 B      Q     4    119 53
# 2   2 2016-05-16 A      W     4    112 64
# 3   3 2016-05-17 B      W     1    101 70
# 4   4 2016-05-18 B      Q     3    103 56
# 5   5 2016-05-19 A      Q     2    116 61
# 6   6 2016-05-20 A      Q     4    104 65
# 7   7 2016-05-21 A      E     1    100 63
# 8   8 2016-05-22 C      W     1    119 50
# 9   9 2016-05-23 B      E     3    120 51
# 10 10 2016-05-24 C      Q     1    103 65
# 11 11 2016-05-25 A      E     5    120 50
# 12 12 2016-05-26 C      Q     1    106 61
# 13 13 2016-05-27 A      E     4    110 69
# 14 14 2016-05-28 C      E     3    104 54
# 15 15 2016-05-29 C      E     3    112 58
# 16 16 2016-05-30 C      Q     1    107 51
# 17 17 2016-05-31 A      E     3    115 61
# 18 18 2016-06-01 C      W     1    110 52
# 19 19 2016-06-02 B      W     1    107 64
# 20 20 2016-06-03 B      E     2    111 54
# 21 21 2016-06-04 C      W     2    107 61
# ...

# %% [markdown]
# ## Referencias
#
# [readxl package](http://readxl.tidyverse.org/)
